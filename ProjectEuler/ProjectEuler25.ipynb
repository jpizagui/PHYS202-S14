# %%
fib = []
fib.append(1)
fib.append(1)
print fib
for i in range(2,10000):
    fib.append(fib[i-2] + fib[i-1])
    
for i in range(len(fib)):
    num = fib[i]
    num = str(num)
    if len(num) == 1000:
        print "The First Term with more than 1000 digits is: ", i+1 #add 1 to index because it starts at 0, 
                                                                    #conventionially starts at 1 For Fib sequence
        print "Here is the number: "
        print num
        break
# Out:
# [1, 1]
# The First Term with more than 1000 digits is:
#  4782
# Here is the number:
# ...
